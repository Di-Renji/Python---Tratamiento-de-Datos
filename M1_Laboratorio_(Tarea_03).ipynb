# %% [markdown]
# # ***INICIO***

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('top10s.csv', encoding='ISO-8859-1')

# %% [markdown]
# # ***FILTROS***

# %% [markdown]
# 1) Listar solo los géneros

# %%
data['top genre']
# Out:
# 0           neo mellow
# 1      detroit hip hop
# 2            dance pop
# 3            dance pop
# 4                  pop
#             ...
# 598          dance pop
# 599                pop
# 600          dance pop
# 601          dance pop
# 602         electropop
# Name: top genre, Length: 603, dtype: object

# %%
data.loc[:, ('top genre')].unique()
# Out:
# array(['neo mellow', 'detroit hip hop', 'dance pop', 'pop',
#        'canadian pop', 'hip pop', 'barbadian pop', 'atl hip hop',
#        'australian pop', 'indie pop', 'art pop', 'colombian pop',
#        'big room', 'british soul', 'chicago rap', 'acoustic pop',
#        'permanent wave', 'boy band', 'baroque pop', 'celtic rock',
#        'electro', 'complextro', 'canadian hip hop', 'candy pop',
#        'alaska indie', 'folk-pop', 'metropopolis', 'house',
#        'australian hip hop', 'electropop', 'australian dance',
#        'hollywood', 'canadian contemporary r&b',
#        'irish singer-songwriter', 'tropical house', 'belgian edm',
#        'french indie pop', 'hip hop', 'danish pop', 'latin',
#        'canadian latin', 'electronic trap', 'edm', 'electro house',
#        'downtempo', 'brostep', 'contemporary country', 'moroccan pop',
#        'escape room', 'alternative r&b'], dtype=object)

# %% [markdown]
# 2) Filtrar Canciones de Longitud mayor que el promedio

# %% [markdown]
# *Sacar el promedio con .mean() y luego filtrar las canciones mayores que el promedio.*

# %%
promedio = data.dur.mean()
promedio
# Out:
# 224.67495854063017

# %%
filtro = data.dur > promedio
filtro
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 598    False
# 599    False
# 600     True
# 601    False
# 602    False
# Name: dur, Length: 603, dtype: bool

# %%
data.loc[filtro]
# Out:
#      Unnamed: 0                                              title  ... spch pop
# 1             2                               Love The Way You Lie  ...   23  82
# 3             4                                        Bad Romance  ...    4  79
# 7             8                                            Secrets  ...    4  77
# 9            10                           Only Girl (In The World)  ...    4  73
# 10           11          Club Can't Handle Me (feat. David Guetta)  ...    3  73
# ..          ...                                                ...  ...  ...  ..
# 582         583                                        Higher Love  ...    3  88
# 589         590                        Giant (with Rag'n'Bone Man)  ...    4  84
# 592         593                     Girls Like You (feat. Cardi B)  ...    5  81
# 594         595                          No Guidance (feat. Drake)  ...   15  81
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...  ...   34  70
#
# ...

# %% [markdown]
#  Mostrar solo la canción el artista y la duración de la canción. *texto en cursiva*

# %%
data.loc[filtro, ('artist', 'dur')]
# Out:
#             artist  dur
# 1           Eminem  263
# 3        Lady Gaga  295
# 7      OneRepublic  225
# 9          Rihanna  235
# 10        Flo Rida  235
# ..             ...  ...
# 582           Kygo  228
# 589  Calvin Harris  229
# 592       Maroon 5  236
# 594    Chris Brown  261
# 600      DJ Khaled  260
#
# [269 rows x 2 columns]

# %% [markdown]
# 3) Listar los artistas que hicieron canciones en el 2019

# %% [markdown]
# *Mostrar solo la columna del artista y su canción*

# %%
filtroanio = data.year==2019
filtroanio
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 598     True
# 599     True
# 600     True
# 601     True
# 602     True
# Name: year, Length: 603, dtype: bool

# %%
data.loc[filtroanio, ('title', 'artist')]
# Out:
#                                                  title            artist
# 572                                           Memories          Maroon 5
# 573                                Lose You To Love Me      Selena Gomez
# 574                                  Someone You Loved     Lewis Capaldi
# 575                                           Señorita      Shawn Mendes
# 576                                  How Do You Sleep?         Sam Smith
# 577  South of the Border (feat. Camila Cabello & Ca...        Ed Sheeran
# 578                             Trampoline (with ZAYN)             SHAED
# 579                                            Happier        Marshmello
# 580                                        Truth Hurts             Lizzo
# 581         Good as Hell (feat. Ariana Grande) - Remix             Lizzo
# 582                                        Higher Love              Kygo
# 583                                         Only Human    Jonas Brothers
# ...

# %% [markdown]
# # ***ORDENAR***

# %% [markdown]
# 1) top de canciones más ruidosas (dB)

# %%
ruidosas = data.sort_values(by="dB", ascending=False)
ruidosas
# Out:
#      Unnamed: 0                          title  ... spch pop
# 108         109       What Makes You Beautiful  ...    7  78
# 198         199                       Pom Poms  ...    9  52
# 116         117                      Starships  ...    8  73
# 498         499                       Rich Boy  ...    5  55
# 30           31                              3  ...    5  62
# ..          ...                            ...  ...  ...  ..
# 471         472                           Love  ...    3  72
# 241         242                      Partition  ...   29  65
# 436         437  Beautiful Birds (feat. Birdy)  ...    3  36
# 431         432                          Start  ...    4  47
# 442         443              Million Years Ago  ...    0   0
#
# [603 rows x 15 columns]

# %% [markdown]
# 2) top de canciones más largas

# %%
largas = data.sort_values(by="dur", ascending=False)
largas
# Out:
#      Unnamed: 0                                              title  ... spch pop
# 188         189                                                TKO  ...   24  58
# 422         423  Wish That You Were Here - From Miss Peregrine...  ...    3  57
# 63           64                                            Monster  ...   20  73
# 162         163                             Lose Yourself to Dance  ...    6  72
# 194         195                                Take Back the Night  ...   16  54
# ..          ...                                                ...  ...  ...  ..
# 581         582         Good as Hell (feat. Ariana Grande) - Remix  ...    6  90
# 492         493          Reality (feat. Janieck Devy) - Radio Edit  ...    4  59
# 174         175                       I Love It (feat. Charli XCX)  ...    3  67
# 591         592                    All Around The World (La La La)  ...    3  82
# 330         331                                      Mark My Words  ...    3  63
#
# ...

# %% [markdown]
# 3) top de canciones más ruidosas y más largas.

# %%
ruidosasylargas = ruidosas.sort_values(by="dur", ascending=False)
ruidosasylargas
# Out:
#      Unnamed: 0                                              title  ... spch pop
# 188         189                                                TKO  ...   24  58
# 422         423  Wish That You Were Here - From Miss Peregrine...  ...    3  57
# 63           64                                            Monster  ...   20  73
# 162         163                             Lose Yourself to Dance  ...    6  72
# 194         195                                Take Back the Night  ...   16  54
# ..          ...                                                ...  ...  ...  ..
# 334         335                               Reality - Radio Edit  ...    3  61
# 492         493          Reality (feat. Janieck Devy) - Radio Edit  ...    4  59
# 174         175                       I Love It (feat. Charli XCX)  ...    3  67
# 591         592                    All Around The World (La La La)  ...    3  82
# 330         331                                      Mark My Words  ...    3  63
#
# ...

# %% [markdown]
# # ***AGRUPAR Y GRAFICAR***

# %% [markdown]
# 1) generos con las canciones más largas de duración más largos  (agrupar por género y sacar máximo de canción)

# %%
filtro_ayg_1 = data.loc[:, ('title', 'top genre', 'dur')]
agrupar_ayg_1 = filtro_ayg_1.groupby("top genre").max()  
agrupar_ayg_1.head(5)
# Out:
#                                                              title  dur
# top genre
# acoustic pop                                          Turning Page  255
# alaska indie                                         Foolish Games  250
# alternative r&b                            Talk (feat. Disclosure)  198
# art pop          Wish That You Were Here - From Miss Peregrine...  403
# atl hip hop                                  OMG (feat. will.i.am)  329

# %%
nuevo = agrupar_ayg_1.head(3)
genero = "top genre"
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(nuevo.title, nuevo.dur)
plt.show()

# %% [markdown]
# 2) Años con su promedio de bailable (agrupar por año y sacar el promedio de dnce)

# %%
filtro_ayg_2 = data.loc[:, ('year', 'dnce')]
agrupar_ayg_2 = filtro_ayg_2.groupby("year").mean()  
agrupar_ayg_2
# Out:
#            dnce
# year
# 2010  64.529412
# 2011  63.641509
# 2012  65.714286
# 2013  62.042254
# 2014  62.534483
# 2015  63.663158
# 2016  63.325000
# 2017  65.369231
# 2018  67.203125
# 2019  69.709677

# %% [markdown]
# 3) años con su promedio de ruido (dB)

# %%
filtro_ayg_3 = data.loc[:, ('year', 'dB')]
agrupar_ayg_3 = filtro_ayg_3.groupby("year").mean()  
agrupar_ayg_3
# Out:
#             dB
# year
# 2010 -4.901961
# 2011 -5.018868
# 2012 -4.857143
# 2013 -5.140845
# 2014 -5.775862
# 2015 -5.621053
# 2016 -6.712500
# 2017 -5.615385
# 2018 -5.671875
# 2019 -5.774194

# %% [markdown]
# # ***HEAD / TAIL***

# %% [markdown]
# 1) Sacar los 3 años con más música más ruidosa (promedio dB)

# %%
filtromasruidosa = data.loc[:,("year", "dB")]  
agruparaniomasruidosa = filtromasruidosa.groupby("year").mean()  
ordenarmasruidosa = agruparaniomasruidosa.sort_values(by="dB", ascending=False)
ordenarmasruidosa.head(3)
# Out:
#             dB
# year
# 2012 -4.857143
# 2010 -4.901961
# 2011 -5.018868

# %% [markdown]
# 2) Sacar los 3 años con más música más bailable (promedio dnce)

# %%
filtromasbailable = data.loc[:,("year", "dnce")]     # filtro para reportar solo el "year" y el "dnce"
agruparaniomasbailable = filtromasbailable.groupby("year").mean()   # agrupa los años y saca el promedio de "dnce" por cada año
ordenarmasbailable = agruparaniomasbailable.sort_values(by="dnce", ascending=False) # Ordnea por mas bailable
ordenarmasbailable.head(3) # Reportar los 3 años mas bailables
# Out:
#            dnce
# year
# 2019  69.709677
# 2018  67.203125
# 2012  65.714286

# %% [markdown]
# 3) Sacar los 3 artistas con música más bailable (promedio dnce)

# %%
filtromasbailable2 = data.loc[:,("artist", "dnce")]  
agruparaniomasbailable2 =filtromasbailable2.groupby("artist").mean()  
ordenarmasbailable2 = agruparaniomasbailable2.sort_values(by="artist", ascending=False)
ordenarmasbailable2.head(3)
# Out:
#                 dnce
# artist
# will.i.am  80.000000
# fun.       52.500000
# Zedd       61.166667

# %% [markdown]
# 4) Sacar los 3 artistas con música más popular  (promedio popular)

# %%
filtromaspopular = data.loc[:,("artist", "pop")]  
agruparartistamaspop = filtromaspopular.groupby("artist").mean()  
ordenarmaspopular = agruparartistamaspop.sort_values(by="artist", ascending=False)
ordenarmaspopular.head(3)
# Out:
#                  pop
# artist
# will.i.am  68.000000
# fun.       67.500000
# Zedd       67.333333
